# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import psycopg2
from data_preparation import DataPreparation
import matplotlib.pyplot as plt
from statsmodels.stats.proportion import proportions_ztest, proportions_chisquare
from scipy.stats import ttest_ind

# %%
dp = DataPreparation()
dp._read_data()
df = dp._data

# %% [markdown]
# Convert target variable to numeric

# %%
df.died = df.died.map(lambda x: float(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6758 entries, 0 to 6757
# Data columns (total 61 columns):
# district_name         6758 non-null object
# subcounty_name        6758 non-null object
# parish_name           6758 non-null object
# village_name_old      6758 non-null object
# died                  6758 non-null float64
# qn201_know            6758 non-null object
# qn202_know            6758 non-null object
# qn203_know            6758 non-null object
# qn204_know            6758 non-null object
# qn205_know            6758 non-null object
# qn206a_know           6758 non-null object
# qn206b_know           6758 non-null object
# qn206c_know           6758 non-null object
# qn206d_know           6758 non-null object
# qn206_totmalflag5     6758 non-null object
# qn207a_know           6758 non-null object
# qn208_know            6758 non-null object
# qn209a_know           6758 non-null object
# qn209b_know           6758 non-null object
# qn209c_know           6758 non-null object
# qn210_know            6758 non-null object
# qn211a_know           6758 non-null object
# qn211b_know           6758 non-null object
# qn211c_know           6758 non-null object
# qn212_know            6758 non-null object
# qn213_know            6758 non-null object
# qn214_know            6758 non-null object
# qn215_know            6758 non-null object
# qn216_know            6758 non-null object
# qn217_know            6758 non-null object
# qn218_know            6758 non-null object
# qn219_know            6758 non-null object
# qn220_know            6758 non-null object
# qn221_know            6758 non-null object
# qn222_know            6758 non-null object
# qn223_know            6758 non-null object
# qn224_know            6758 non-null object
# qn225_know            6758 non-null object
# qn226_know            6758 non-null object
# qn227_know            6758 non-null object
# qn1001_hhw            6758 non-null object
# qn1002_hhw            6758 non-null object
# qn1003_hhw            6758 non-null object
# qn1004_hhw            6758 non-null object
# qn1005_hhw            6758 non-null object
# qn1006_hhw            6758 non-null object
# qn1007_hhw            6758 non-null object
# qn1008_hhw            6758 non-null object
# qn1009_hhw            6758 non-null object
# qn1010_hhw            6758 non-null object
# qn1011_hhw            6758 non-null object
# qn1012_hhw            6758 non-null object
# qn1013_hhw            6758 non-null object
# qn1014_hhw            6758 non-null object
# qn01_103              6245 non-null object
# qn01_104              6324 non-null object
# qn01_105              6324 non-null object
# qn01_106              6324 non-null object
# totalshops_village    6758 non-null object
# shop_village          6758 non-null object
# qn01_106_binned       6758 non-null object
# dtypes: float64(1), object(60)
# memory usage: 3.1+ MB

# %%
df.iloc[:, 30:]
# Out:
#      qn218_know qn219_know          qn220_know qn221_know     qn222_know  \
# 0           yes       soap       Govt Hospital                  Somewhat
# 1           yes       soap       Govt Hospital                  Somewhat
# 2           yes       soap       Govt Hospital                  Somewhat
# 3           yes       soap       Govt Hospital                  Somewhat
# 4           yes       soap       Govt Hospital
# 5           yes       soap       Govt Hospital
# 6           yes       soap  Govt health center             Not very much
# 7           yes       soap  Govt health center             Not very much
# 8           yes       soap       Govt Hospital                  Somewhat
# 9           yes       soap       Govt Hospital                  Somewhat
# 10          yes       soap    Private Hospital                  Somewhat
# 11          yes       soap    Private Hospital                  Somewhat
# 12          yes       soap    Private Hospital                  Somewhat
# 13          yes       soap    Private Hospital                  Somewhat
# 14          yes       soap       Govt Hospital             Not very much
# 15          yes       soap       Govt Hospital                  Somewhat
# 16          yes       soap       Govt Hospital                  Somewhat
# 17          yes       soap       Govt Hospital                  Somewhat
# 18          yes       soap  Govt health center                  Somewhat
# 19          yes       soap  Govt health center                  Somewhat
# 20          yes       soap       Govt Hospital                 Very much
# 21          yes       soap       Govt Hospital                 Very much
# 22          yes       soap       Govt Hospital                  Somewhat
# 23          yes       soap       Govt Hospital                  Somewhat
# 24          yes       soap               Other                 Very much
# 25          yes       soap               Other                 Very much
# 26           no             Govt health center                  Somewhat
# 27           no             Govt health center                  Somewhat
# 28           no             Govt health center                  Somewhat
# 29           no             Govt health center                  Somewhat
# ...         ...        ...                 ...        ...            ...
# 6728        yes       soap       Govt Hospital                 Very much
# 6729        yes       soap       Govt Hospital                 Very much
# 6730         no                  Govt Hospital                  Somewhat
# 6731         no                  Govt Hospital                  Somewhat
# 6732        yes       soap    Private Hospital                 Very much
# 6733        yes       soap       Govt Hospital                 Very much
# 6734        yes       soap       Govt Hospital                 Very much
# 6735        yes       soap       Govt Hospital                 Very much
# 6736        yes       soap       Govt Hospital             Not very much
# 6737        yes       soap       Govt Hospital             Not very much
# 6738        yes       soap       Govt Hospital             Not very much
# 6739        yes       soap       Govt Hospital             Not very much
# 6740        yes       soap       Govt Hospital             Not very much
# 6741        yes       soap      Private Clinic                  Somewhat
# 6742        yes       soap      Private Clinic                  Somewhat
# 6743         no                  Govt Hospital                 Very much
# 6744         no                  Govt Hospital                 Very much
# 6745         no                  Govt Hospital                 Very much
# 6746         no                  Govt Hospital                 Very much
# 6747        yes       soap       Govt Hospital                  Somewhat
# 6748        yes       soap       Govt Hospital                 Very much
# 6749        yes       soap       Govt Hospital                 Very much
# 6750        yes       soap       Govt Hospital                 Very much
# 6751        yes       soap       Govt Hospital                 Very much
# 6752        yes       soap       Govt Hospital                 Very much
# 6753        yes       soap                11.0                  Somewhat
# 6754        yes       soap       Govt Hospital                 Very much
# 6755        yes       soap       Govt Hospital                 Very much
# 6756        yes       soap                11.0                 Very much
# 6757        yes       soap    Private Hospital                  Somewhat
#
#          qn223_know qn224_know  qn225_know qn226_know qn227_know  \
# 0          Somewhat         12  Female HHH         no
# 1          Somewhat         12  Female HHH         no
# 2          Somewhat         12  Female HHH         no
# 3          Somewhat         12  Female HHH         no
# 4                        other  Female HHH         no
# 5                        other  Female HHH         no
# 6         Very much        1 2    Male HHH        yes        1 4
# 7         Very much        1 2    Male HHH        yes        1 4
# 8          Somewhat        1 2    Male HHH        yes          4
# 9          Somewhat        1 2    Male HHH        yes          4
# 10         Somewhat         15    Male HHH        yes        1 4
# 11         Somewhat         15    Male HHH        yes        1 4
# 12         Somewhat         15    Male HHH        yes        1 4
# 13         Somewhat         15    Male HHH        yes        1 4
# 14         Somewhat         15    Male HHH         no
# 15         Somewhat         15    Male HHH        yes          4
# 16         Somewhat         15    Male HHH        yes          4
# 17         Somewhat      other  Female HHH         no
# 18         Somewhat          2    Male HHH         no
# 19         Somewhat          2    Male HHH         no
# 20        Very much         11    Male HHH        yes          4
# 21        Very much        2 9  Female HHH        yes        1 2
# 22         Somewhat      12 15        Both         no
# 23         Somewhat      12 15        Both         no
# 24        Very much  2 9 13 15    Male HHH         no
# 25        Very much  2 9 13 15    Male HHH         no
# 26         Somewhat          9    Male HHH         no
# 27         Somewhat          9    Male HHH         no
# 28         Somewhat          9    Male HHH         no
# 29         Somewhat          9    Male HHH         no
# ...             ...        ...         ...        ...        ...
# 6728      Very much        2 9  Female HHH        yes          4
# 6729      Very much        2 9  Female HHH        yes          4
# 6730       Somewhat         15  Female HHH        yes          2
# 6731       Somewhat         15  Female HHH        yes          2
# 6732       Somewhat         15    Male HHH        yes          3
# 6733      Very much          9    Male HHH         no
# 6734      Very much          1        Both        yes          4
# 6735      Very much          1        Both        yes          4
# 6736  Not very much          1        Both        yes          4
# 6737  Not very much          1        Both        yes          4
# 6738  Not very much          1        Both        yes          4
# 6739       Somewhat          1  Female HHH        yes          4
# 6740       Somewhat          1  Female HHH        yes          4
# 6741       Somewhat       9 15  Female HHH         no
# 6742       Somewhat       9 15  Female HHH         no
# 6743      Very much         12  Female HHH        yes          4
# 6744      Very much         12  Female HHH        yes          4
# 6745      Very much         12  Female HHH        yes          4
# 6746      Very much         12  Female HHH        yes          4
# 6747       Somewhat         14  Female HHH         no
# 6748      Very much          2  Female HHH        yes          4
# 6749      Very much          2  Female HHH        yes          4
# 6750      Very much          2    Male HHH        yes         10
# 6751      Very much          2    Male HHH        yes         10
# 6752      Very much          2    Male HHH        yes         10
# 6753      Very much          1  Female HHH        yes          4
# 6754      Very much       2 14  Female HHH         no
# 6755      Very much       2 14  Female HHH         no
# 6756       Somewhat          9        Both        yes          4
# 6757       Somewhat          9  Female HHH        yes          4
#
#            ...       qn1012_hhw       qn1013_hhw qn1014_hhw qn01_103 qn01_104  \
# 0          ...               no           Cement       Iron     None     None
# 1          ...               no           Cement       Iron     None     None
# 2          ...               no           Cement       Iron     None     None
# 3          ...               no           Cement       Iron     None     None
# 4          ...              yes  Earth/Sand/Dung       Iron     None     None
# 5          ...              yes  Earth/Sand/Dung       Iron     None     None
# 6          ...              yes  Earth/Sand/Dung       Iron     46.0     male
# 7          ...              yes  Earth/Sand/Dung       Iron     46.0     male
# 8          ...              yes  Earth/Sand/Dung       Iron     60.0     male
# 9          ...              yes  Earth/Sand/Dung       Iron     60.0     male
# 10         ...              yes           Cement       Iron     48.0     male
# 11         ...              yes           Cement       Iron     48.0     male
# 12         ...              yes           Cement       Iron     48.0     male
# 13         ...              yes           Cement       Iron     48.0     male
# 14         ...              yes  Earth/Sand/Dung       Iron     28.0     male
# 15         ...              yes  Earth/Sand/Dung       Iron     23.0     male
# 16         ...              yes  Earth/Sand/Dung       Iron     23.0     male
# 17         ...               no           Cement       Iron     42.0     male
# 18         ...              yes           Cement       Iron     26.0     male
# 19         ...              yes           Cement       Iron     26.0     male
# 20         ...              yes           Cement       Iron     21.0   female
# 21         ...              yes           Cement       Iron     46.0     male
# 22         ...              yes           Cement       Iron     42.0     male
# 23         ...              yes           Cement       Iron     42.0     male
# 24         ...              yes  Earth/Sand/Dung       Iron     50.0     male
# 25         ...              yes  Earth/Sand/Dung       Iron     50.0     male
# 26         ...              yes           Cement       Iron     65.0     male
# 27         ...              yes           Cement       Iron     65.0     male
# 28         ...              yes           Cement       Iron     65.0     male
# 29         ...              yes           Cement       Iron     65.0     male
# ...        ...              ...              ...        ...      ...      ...
# 6728       ...              yes           Cement       Iron     50.0     male
# 6729       ...              yes           Cement       Iron     50.0     male
# 6730       ...              yes           Cement       Iron     40.0     male
# 6731       ...              yes           Cement       Iron     40.0     male
# 6732       ...              yes  Earth/Sand/Dung       Iron     32.0     male
# 6733       ...              yes  Earth/Sand/Dung       Iron     75.0     male
# 6734       ...              yes  Earth/Sand/Dung       Iron     30.0     male
# 6735       ...              yes  Earth/Sand/Dung       Iron     30.0     male
# 6736       ...              yes           Cement       Iron     40.0     male
# 6737       ...              yes           Cement       Iron     40.0     male
# 6738       ...              yes           Cement       Iron     40.0     male
# 6739       ...              yes         Concrete      Other     43.0     male
# 6740       ...              yes         Concrete      Other     43.0     male
# 6741       ...              yes           Cement      Tiles     None     None
# 6742       ...              yes           Cement      Tiles     None     None
# 6743       ...              yes           Cement       Iron     62.0     male
# 6744       ...              yes           Cement       Iron     62.0     male
# 6745       ...              yes           Cement       Iron     62.0     male
# 6746       ...              yes           Cement       Iron     62.0     male
# 6747       ...               no           Cement       Iron     80.0   female
# 6748       ...              yes           Cement       Iron     79.0     male
# 6749       ...              yes           Cement       Iron     79.0     male
# 6750       ...              yes  Earth/Sand/Dung       Iron     None     None
# 6751       ...              yes  Earth/Sand/Dung       Iron     None     None
# 6752       ...              yes  Earth/Sand/Dung       Iron     None     None
# 6753       ...              yes           Cement       Iron     20.0   female
# 6754       ...               no           Cement       Iron     45.0   female
# 6755       ...               no           Cement       Iron     45.0   female
# 6756       ...              yes  Earth/Sand/Dung       Iron     44.0     male
# 6757       ...              yes  Earth/Sand/Dung       Iron     25.0     male
#
#             qn01_105 qn01_106 totalshops_village shop_village qn01_106_binned
# 0               None     None                0.0          0.0         missing
# 1               None     None                0.0          0.0         missing
# 2               None     None                0.0          0.0         missing
# 3               None     None                0.0          0.0         missing
# 4               None     None                0.0          0.0         missing
# 5               None     None                0.0          0.0         missing
# 6     Household Head       S1                0.0          0.0              S1
# 7     Household Head       S1                0.0          0.0              S1
# 8     Household Head       S1                0.0          0.0              S1
# 9     Household Head       S1                0.0          0.0              S1
# 10    Household Head       S1                0.0          0.0              S1
# 11    Household Head       S1                0.0          0.0              S1
# 12    Household Head       S1                0.0          0.0              S1
# 13    Household Head       S1                0.0          0.0              S1
# 14    Household Head       S1                0.0          0.0              S1
# 15    Household Head       S1                0.0          0.0              S1
# 16    Household Head       S1                0.0          0.0              S1
# 17    Household Head       S1                0.0          0.0              S1
# 18    Household Head       S1                0.0          0.0              S1
# 19    Household Head       S1                0.0          0.0              S1
# 20    Household Head       S1                0.0          0.0              S1
# 21    Household Head       S1                0.0          0.0              S1
# 22    Household Head       S1                0.0          0.0              S1
# 23    Household Head       S1                0.0          0.0              S1
# 24    Household Head       S1                0.0          0.0              S1
# 25    Household Head       S1                0.0          0.0              S1
# 26    Household Head       S1                0.0          0.0              S1
# 27    Household Head       S1                0.0          0.0              S1
# 28    Household Head       S1                0.0          0.0              S1
# 29    Household Head       S1                0.0          0.0              S1
# ...              ...      ...                ...          ...             ...
# 6728  Household Head       S1                1.0          1.0              S1
# 6729  Household Head       S1                1.0          1.0              S1
# 6730  Household Head       S1                1.0          1.0              S1
# 6731  Household Head       S1                1.0          1.0              S1
# 6732  Household Head       S1                1.0          1.0              S1
# 6733  Household Head       S1                1.0          1.0              S1
# 6734  Household Head       S1                1.0          1.0              S1
# 6735  Household Head       S1                1.0          1.0              S1
# 6736  Household Head       S1                1.0          1.0              S1
# 6737  Household Head       S1                1.0          1.0              S1
# 6738  Household Head       S1                1.0          1.0              S1
# 6739  Household Head       S1                1.0          1.0              S1
# 6740  Household Head       S1                1.0          1.0              S1
# 6741            None     None                1.0          1.0         missing
# 6742            None     None                1.0          1.0         missing
# 6743  Household Head       S1                1.0          1.0              S1
# 6744  Household Head       S1                1.0          1.0              S1
# 6745  Household Head       S1                1.0          1.0              S1
# 6746  Household Head       S1                1.0          1.0              S1
# 6747  Household Head       S1                1.0          1.0              S1
# 6748  Household Head       S1                1.0          1.0              S1
# 6749  Household Head       S1                1.0          1.0              S1
# 6750            None     None                1.0          1.0         missing
# 6751            None     None                1.0          1.0         missing
# 6752            None     None                1.0          1.0         missing
# 6753  Household Head       S1                1.0          1.0              S1
# 6754  Household Head       S1                1.0          1.0              S1
# 6755  Household Head       S1                1.0          1.0              S1
# 6756  Household Head       S1                1.0          1.0              S1
# 6757  Household Head       S1                1.0          1.0              S1
#
# [6758 rows x 31 columns]

# %% [markdown]
# ## Run statistical tests against each column

# %% [markdown]
# Convert numberic variables to number data types

# %%
df.qn206_totmalflag5 = df.qn206_totmalflag5.map(lambda x: int(x))
df.qn1001_hhw = df.qn1001_hhw.map(lambda x: None if x=='' else float(x))
df.qn1009_hhw = df.qn1009_hhw.map(lambda x: None if x=='' else float(x))
df.qn01_103 = df.qn01_103.map(lambda x: None if pd.isnull(x) else float(x))
df.totalshops_village = df.totalshops_village.map(lambda x: float(x))

# %% [markdown]
# For each categorical feature we run a separate statistical test:
#
# * If the feature has more than 2 levels we run a Chi-squared test
# * If the feature has 2 levels we run a z-test
# * If the feature has less than 2 levels no test in possibile
#
# **Missing answers** are coded differently than negative answers.
#
# For each numerical variable a separate t-test is run.

# %%
def encode_missing_answers(feature):
    df[feature] = df[feature].map(lambda f: 'missing' if f=='' else f)

# %%
def encode_null_values(feature):
    df[feature] = df[feature].map(lambda f: 'missing' if pd.isnull(f) else f)

# %%
def count_number_of_levels(feature):
    return len(df.groupby(feature).count().index.tolist())

# %%
def z_test_two_proportions(feature):
    print
    print 'Group proportions for feature %s:' % feature
    print
    print df.groupby(feature).mean()['died']
    successes = np.array(df.groupby(feature).sum()['died'])
    trials = np.array(df.groupby(feature).count()['died'])
    z_statistic, p_value = proportions_ztest(successes, trials, value=0, alternative='two-sided')
    print
    print 'z_test of difference in proportions has %2.3f p-value.' % p_value
    print
    return p_value

# %%
def chisquare_test_N_proportions(feature):
    print
    print 'Group proportions for feature %s:' % feature
    print
    print df.groupby(feature).mean()['died']
    successes = np.array(df.groupby(feature).sum()['died'])
    trials = np.array(df.groupby(feature).count()['died'])
    chisq = proportions_chisquare(successes, trials)
    z_statistic, p_value = chisq[0:2]
    print
    print 'z_test of difference in proportions has %2.3f p-value.' % p_value
    print
    return p_value

# %%
def t_test_means(feature):
    prop_nas = np.mean(df[feature].isnull())
    if prop_nas > 0.10:
        return None
    df[feature] = df[feature].fillna(np.mean(df[feature]))
    print
    print 'Group means for feature %s:' % feature
    print df.groupby('died').agg({feature: [np.mean]})[feature]['mean']
    a = df[df.died==1.0][feature]
    b = df[df.died==0.0][feature]
    t_statistic, p_value = ttest_ind(a, b, axis=0, equal_var=True)
    print
    print 't_test of difference in means has %2.3f p-value.' % p_value
    return p_value

# %%
def run_test(feature):
    print
    print
    print
    print 'Testing feature %s' % feature
    p_value = None
    if np.any(df[feature] == ''):
        encode_missing_answers(feature)
    if np.any(df[feature].isnull()):
        encode_null_values(feature)
    num_levels = count_number_of_levels(feature)
    if num_levels>2:
        p_value = chisquare_test_N_proportions(feature)
    elif num_levels==2:
        p_value = z_test_two_proportions(feature)
    else:
        print '%s has %d levels' % (feature, num_levels)
    return p_value

# %%
categorical_features = df.dtypes[df.dtypes == 'object'].index.tolist()
quantitative_features = df.dtypes[df.dtypes != 'object'].index.tolist()
quantitative_features.remove('died')
test_results = []
for cf in categorical_features:
    test_results.append((cf, run_test(cf)))
for qf in quantitative_features:
    test_results.append((qf, t_test_means(qf)))
# Out:
# Testing feature district_name
#
# Group proportions for feature district_name:
#
# district_name
# 13 Jinja    0.072756
# 16 Mpigi    0.036559
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.000 p-value.
#
#
#
#
# Testing feature subcounty_name
#
# Group proportions for feature subcounty_name:
#
# subcounty_name
# BUGEMBE                0.078194
# KAKIRA                 0.044118
# MAFUBIRA               0.071362
# MPINGI TOWN COUNCIL    0.036559
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.000 p-value.
#
#
#
#
# Testing feature parish_name
#
# Group proportions for feature parish_name:
#
# parish_name
# BUBEZI             0.032787
# BUDUMBULI EAST     0.117647
# BUDUMBULI WEST     0.100000
# BUGEMBE WARD       0.036364
# BUMOOZI            0.055215
# BUWEKULA           0.055233
# BUWENDA            0.114688
# KAFUMU             0.026820
# KAKOOLA            0.050167
# KATENDE            0.074074
# KATENDE WARD       0.142857
# KONKOMA            0.031250
# KYALI              0.022167
# LWANGA             0.040984
# MAFUBIRA           0.055866
# MAWOITO            0.044118
# MAZIBA             0.039387
# NAKANYONYI         0.051282
# NAKANYONYI WARD    0.057377
# NAMULESA           0.048649
# WANYAMA            0.120690
# WANYAMA WARD       0.043716
# WANYANGE           0.073232
# WARD A             0.045016
# WARD B             0.028571
# WARD C             0.015873
# WARD D             0.021277
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.000 p-value.
#
#
#
#
# Testing feature village_name_old
#
# Group proportions for feature village_name_old:
#
# village_name_old
# 1301    0.121212
# 1302    0.106667
# 1303    0.027027
# 1304    0.152778
# 1305    0.105263
# 1306    0.048387
# 1307    0.142857
# 1308    0.089286
# 1309    0.074074
# 1310    0.063492
# 1311    0.042254
# 1312    0.044118
# 1313    0.041096
# 1314    0.095890
# 1315    0.085714
# 1316    0.084746
# 1317    0.120690
# 1318    0.068966
# 1319    0.030303
# 1320    0.048387
# 1321    0.056338
# 1322    0.017544
# 1323    0.052632
# 1324    0.041667
# 1325    0.125000
# 1326    0.046875
# 1327    0.031250
# 1328    0.045455
# 1329    0.032787
# 1330    0.064516
#           ...
# 1632    0.031250
# 1633    0.030303
# 1634    0.017241
# 1635    0.030303
# 1636    0.063492
# 1637    0.015152
# 1638    0.000000
# 1639    0.017857
# 1640    0.062500
# 1641    0.039474
# 1642    0.024691
# 1643    0.041667
# 1644    0.055556
# 1645    0.000000
# 1646    0.000000
# 1647    0.000000
# 1648    0.040000
# 1649    0.000000
# 1650    0.000000
# 1651    0.063492
# 1652    0.083333
# 1653    0.027397
# 1654    0.056338
# 1655    0.061538
# 1656    0.018519
# 1657    0.045455
# 1658    0.111111
# 1659    0.000000
# 1660    0.066667
# 18      0.000000
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.000 p-value.
#
#
#
#
# Testing feature qn201_know
#
# Group proportions for feature qn201_know:
#
# qn201_know
# no     0.057306
# yes    0.050079
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.189 p-value.
#
#
#
#
# Testing feature qn202_know
#
# Group proportions for feature qn202_know:
#
# qn202_know
# missing    0.088889
# no         0.000000
# yes        0.053349
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.184 p-value.
#
#
#
#
# Testing feature qn203_know
#
# Group proportions for feature qn203_know:
#
# qn203_know
# a              0.000000
# a b c          0.000000
# a c            0.058824
# a c d          0.166667
# a c d other    0.000000
# b              0.090909
# b c            0.037037
# b c other      0.000000
# b other        0.000000
# c              0.053290
# c d            0.040000
# c other        0.069767
# d              0.000000
# d other        0.000000
# missing        0.047059
# other          0.000000
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.997 p-value.
#
#
#
#
# Testing feature qn204_know
#
# Group proportions for feature qn204_know:
#
# qn204_know
# missing    0.060384
# no         0.038874
# yes        0.047407
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.016 p-value.
#
#
#
#
# Testing feature qn205_know
#
# Group proportions for feature qn205_know:
#
# qn205_know
# 1            0.075000
# 1 2          0.000000
# 1 2 3        0.125000
# 1 2 other    0.000000
# 1 3          0.013699
# 1 3 other    0.000000
# 1 other      0.000000
# 2            0.046845
# 2 3          0.102740
# 2 3 other    0.103448
# 2 other      0.054945
# 3            0.030172
# 3 88         0.000000
# 3 other      0.078947
# 88           0.037736
# missing      0.056643
# other        0.038328
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.072 p-value.
#
#
#
#
# Testing feature qn206a_know
#
# Group proportions for feature qn206a_know:
#
# qn206a_know
# missing    0.052500
# no         0.051007
# yes        0.054572
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.831 p-value.
#
#
#
#
# Testing feature qn206b_know
#
# Group proportions for feature qn206b_know:
#
# qn206b_know
# missing    0.000000
# no         0.062500
# yes        0.053292
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.705 p-value.
#
#
#
#
# Testing feature qn206c_know
#
# Group proportions for feature qn206c_know:
#
# qn206c_know
# missing    0.072581
# no         0.059925
# yes        0.051874
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.282 p-value.
#
#
#
#
# Testing feature qn206d_know
#
# Group proportions for feature qn206d_know:
#
# qn206d_know
# missing    0.052045
# no         0.047213
# yes        0.055378
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.463 p-value.
#
#
#
#
# Testing feature qn207a_know
#
# Group proportions for feature qn207a_know:
#
# qn207a_know
# 1) Direct contact with someone who has malaria    0.060976
# 2) Mosquito bites                                 0.055750
# 3) Drinking water containing mosquito eggs        0.047658
# 4) Eating certain kinds of mangos                 0.027397
# missing                                           0.048673
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.466 p-value.
#
#
#
#
# Testing feature qn208_know
#
# Group proportions for feature qn208_know:
#
# qn208_know
# missing    0.053239
# no         0.058548
# yes        0.050981
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.509 p-value.
#
#
#
#
# Testing feature qn209a_know
#
# Group proportions for feature qn209a_know:
#
# qn209a_know
# No, none of them     0.043426
# Yes, all of them     0.047619
# Yes, most of them    0.069884
# Yes, some of them    0.047804
# missing              0.055733
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.170 p-value.
#
#
#
#
# Testing feature qn209b_know
#
# Group proportions for feature qn209b_know:
#
# qn209b_know
# No, none of them     0.035752
# Yes, all of them     0.052632
# Yes, most of them    0.073477
# Yes, some of them    0.052815
# missing              0.055072
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.032 p-value.
#
#
#
#
# Testing feature qn209c_know
#
# Group proportions for feature qn209c_know:
#
# qn209c_know
# No, none of them     0.042867
# Yes, all of them     0.000000
# Yes, most of them    0.050633
# Yes, some of them    0.048611
# missing              0.056814
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.226 p-value.
#
#
#
#
# Testing feature qn210_know
#
# Group proportions for feature qn210_know:
#
# qn210_know
# missing    0.047433
# no         0.066625
# yes        0.049890
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.024 p-value.
#
#
#
#
# Testing feature qn211a_know
#
# Group proportions for feature qn211a_know:
#
# qn211a_know
# No, none of them     0.043237
# Yes, all of them     0.040541
# Yes, most of them    0.071970
# Yes, some of them    0.042263
# missing              0.057858
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.027 p-value.
#
#
#
#
# Testing feature qn211b_know
#
# Group proportions for feature qn211b_know:
#
# qn211b_know
# No, none of them     0.038388
# Yes, all of them     0.049180
# Yes, most of them    0.071730
# Yes, some of them    0.048630
# missing              0.056974
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.051 p-value.
#
#
#
#
# Testing feature qn211c_know
#
# Group proportions for feature qn211c_know:
#
# qn211c_know
# No, none of them     0.043728
# Yes, all of them     0.083333
# Yes, most of them    0.104167
# Yes, some of them    0.066148
# missing              0.054222
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.072 p-value.
#
#
#
#
# Testing feature qn212_know
#
# Group proportions for feature qn212_know:
#
# qn212_know
# missing    0.166667
# no         0.067644
# yes        0.050980
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.056 p-value.
#
#
#
#
# Testing feature qn213_know
#
# Group proportions for feature qn213_know:
#
# qn213_know
# a            0.049223
# a b          0.045652
# a b c        0.000000
# a b d        0.000000
# a b e        0.100000
# a b other    0.000000
# a c          0.088083
# a c e        0.000000
# a c other    0.000000
# a d          0.083333
# a e          0.000000
# a other      0.000000
# b            0.054054
# b c          0.000000
# c            0.111111
# c other      0.000000
# d            0.000000
# e            0.000000
# f            0.000000
# missing      0.068309
# other        0.074074
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.362 p-value.
#
#
#
#
# Testing feature qn214_know
#
# Group proportions for feature qn214_know:
#
# qn214_know
# missing    0.074074
# no         0.046948
# yes        0.052953
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.456 p-value.
#
#
#
#
# Testing feature qn215_know
#
# Group proportions for feature qn215_know:
#
# qn215_know
# 1                0.055241
# 1 2              0.054264
# 1 2 5            0.000000
# 1 2 5 6          0.000000
# 1 2 5 other      0.000000
# 1 2 6            0.086957
# 1 2 6 7          0.000000
# 1 2 6 7 other    0.000000
# 1 2 6 other      0.111111
# 1 2 7            0.055556
# 1 2 7 other      0.000000
# 1 2 other        0.000000
# 1 3              0.250000
# 1 3 7            0.000000
# 1 4              0.000000
# 1 4 6            0.000000
# 1 5              0.062500
# 1 5 6            0.000000
# 1 5 6 other      0.000000
# 1 5 7            0.111111
# 1 5 other        0.000000
# 1 6              0.042122
# 1 6 7            0.059459
# 1 6 7 other      0.181818
# 1 6 other        0.034483
# 1 7              0.052247
# 1 7 other        0.047619
# 1 other          0.046358
# 2                0.038462
# 2 4 7            0.000000
# 2 5 other        0.000000
# 2 6              0.048193
# 2 6 7            0.000000
# 2 6 7 other      0.000000
# 2 6 other        0.100000
# 2 7              0.000000
# 2 7 other        0.000000
# 2 other          0.000000
# 3 other          0.000000
# 4 7              0.000000
# 5                0.000000
# 5 6              0.111111
# 5 6 7            0.000000
# 5 7              0.000000
# 5 other          0.100000
# 6                0.069172
# 6 7              0.073604
# 6 7 other        0.058824
# 6 other          0.014706
# 7                0.033291
# 7 other          0.032258
# missing          0.058667
# other            0.067194
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.742 p-value.
#
#
#
#
# Testing feature qn216_know
#
# Group proportions for feature qn216_know:
#
# qn216_know
# Borehole               0.048721
# Lakes and/or rivers    0.000000
# Other                  0.032258
# Rainwater              0.020833
# Spring                 0.040771
# Tap water              0.063856
# Water Pumps            0.112903
# Well                   0.040521
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.002 p-value.
#
#
#
#
# Testing feature qn217_know
#
# Group proportions for feature qn217_know:
#
# qn217_know
# Every time          0.059283
# Most of the time    0.035681
# Never               0.166667
# Rarely              0.042945
# Sometimes           0.076389
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.000 p-value.
#
#
#
#
# Testing feature qn218_know
#
# Group proportions for feature qn218_know:
#
# qn218_know
# missing    0.166667
# no         0.043668
# yes        0.054246
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.235 p-value.
#
#
#
#
# Testing feature qn219_know
#
# Group proportions for feature qn219_know:
#
# qn219_know
# missing    0.044733
# other      0.031250
# soap       0.054368
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.484 p-value.
#
#
#
#
# Testing feature qn220_know
#
# Group proportions for feature qn220_know:
#
# qn220_know
# 11.0                  0.015873
# At mothers home      0.000000
# Govt Hospital         0.056276
# Govt health center    0.050095
# NGO clinic            0.000000
# Other                 0.020833
# Private Clinic        0.027027
# Private Hospital      0.047337
# missing               0.000000
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.762 p-value.
#
#
#
#
# Testing feature qn221_know
# qn221_know has 1 levels
#
#
#
# Testing feature qn222_know
#
# Group proportions for feature qn222_know:
#
# qn222_know
# Not at all       0.057143
# Not very much    0.037879
# Somewhat         0.055078
# Very much        0.054926
# missing          0.059172
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.363 p-value.
#
#
#
#
# Testing feature qn223_know
#
# Group proportions for feature qn223_know:
#
# qn223_know
# Not at all       0.000000
# Not very much    0.041929
# Somewhat         0.054868
# Very much        0.053557
# missing          0.058201
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.475 p-value.
#
#
#
#
# Testing feature qn224_know
#
# Group proportions for feature qn224_know:
#
# qn224_know
# 1                        0.064439
# 1 10                     0.000000
# 1 10 14                  0.000000
# 1 11                     0.047619
# 1 11 15                  0.047619
# 1 11 other               0.000000
# 1 12                     0.000000
# 1 12 13                  0.750000
# 1 12 14 15               0.000000
# 1 12 15                  0.000000
# 1 12 other               0.000000
# 1 13                     0.000000
# 1 13 14                  0.200000
# 1 13 14 other            0.000000
# 1 13 15                  0.000000
# 1 13 15 other            0.000000
# 1 14                     0.000000
# 1 15                     0.067485
# 1 15 other               0.000000
# 1 2                      0.045226
# 1 2 10 15                0.000000
# 1 2 11                   0.125000
# 1 2 11 13 14 15          0.000000
# 1 2 11 15                0.000000
# 1 2 12                   0.000000
# 1 2 12 13 14 15 other    0.000000
# 1 2 12 13 14 other       0.000000
# 1 2 12 15 other          0.000000
# 1 2 13                   0.500000
# 1 2 13 14                0.000000
#                            ...
# 6                        0.000000
# 6 11 15                  0.400000
# 7                        0.000000
# 7 15                     0.000000
# 8 10 13 15               0.000000
# 8 15                     0.000000
# 9                        0.046243
# 9 10                     0.000000
# 9 10 13                  0.000000
# 9 10 13 14 15 other      0.000000
# 9 10 14                  0.000000
# 9 10 15                  0.333333
# 9 11                     0.044118
# 9 11 12 15               0.000000
# 9 11 14                  0.000000
# 9 11 15                  0.000000
# 9 12                     0.071429
# 9 12 13 15               0.000000
# 9 12 15                  0.000000
# 9 12 15 other            0.000000
# 9 13                     0.000000
# 9 13 14 15 other         0.000000
# 9 13 15                  0.000000
# 9 13 15 other            0.000000
# 9 14                     0.000000
# 9 14 15                  0.000000
# 9 15                     0.026316
# 9 15 other               0.000000
# 9 other                  0.000000
# other                    0.052632
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.900 p-value.
#
#
#
#
# Testing feature qn225_know
#
# Group proportions for feature qn225_know:
#
# qn225_know
# Both          0.050788
# Female HHH    0.050961
# Male HHH      0.055641
# Other         0.055556
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.861 p-value.
#
#
#
#
# Testing feature qn226_know
#
# Group proportions for feature qn226_know:
#
# qn226_know
# no     0.05547
# yes    0.05238
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.608 p-value.
#
#
#
#
# Testing feature qn227_know
#
# Group proportions for feature qn227_know:
#
# qn227_know
# 1              0.044061
# 1 10           0.000000
# 1 2            0.042553
# 1 2 3          0.000000
# 1 2 3 4        0.000000
# 1 2 3 4 5      0.000000
# 1 2 4          0.018182
# 1 2 4 10       0.000000
# 1 2 4 5        0.285714
# 1 2 4 9        0.000000
# 1 2 4 other    0.000000
# 1 2 5          0.000000
# 1 3            0.000000
# 1 3 4          0.058824
# 1 3 other      0.000000
# 1 4            0.033079
# 1 4 10         0.000000
# 1 4 5          0.000000
# 1 4 6          0.000000
# 1 4 9          0.500000
# 1 5            0.000000
# 1 5 10         0.000000
# 1 7            0.333333
# 1 9            0.000000
# 1 other        0.000000
# 10             0.065217
# 13             0.000000
# 2              0.056818
# 2 10           0.000000
# 2 11           0.000000
#                  ...
# 2 5            0.032258
# 2 7            0.000000
# 2 8            0.500000
# 2 other        0.000000
# 3              0.064103
# 3 10           0.000000
# 3 4            0.021277
# 3 4 7          0.000000
# 3 5            0.000000
# 4              0.062367
# 4 10           0.076923
# 4 5            0.032609
# 4 5 10         0.000000
# 4 5 6          0.000000
# 4 5 7          0.000000
# 4 55           0.000000
# 4 6            0.250000
# 4 7            0.000000
# 4 8            0.250000
# 4 9            0.333333
# 4 other        0.000000
# 5              0.029703
# 5 10           0.000000
# 5 8            0.000000
# 55             0.000000
# 6              0.153846
# 7              0.052632
# 9              0.000000
# missing        0.055470
# other          0.030864
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.436 p-value.
#
#
#
#
# Testing feature qn1002_hhw
#
# Group proportions for feature qn1002_hhw:
#
# qn1002_hhw
# Catholic                 0.041567
# Muslim                   0.060284
# No religion              0.000000
# Other                    0.047619
# Protestant               0.061611
# SAVED/Born again         0.064343
# Seventh Day Adventist    0.009259
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.010 p-value.
#
#
#
#
# Testing feature qn1003_hhw
#
# Group proportions for feature qn1003_hhw:
#
# qn1003_hhw
# no     0.056469
# yes    0.052435
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.550 p-value.
#
#
#
#
# Testing feature qn1004_hhw
#
# Group proportions for feature qn1004_hhw:
#
# qn1004_hhw
# Almost every day         0.017341
# At least once a week     0.049155
# Daily                    0.041322
# Less than once a week    0.049202
# Not at all               0.057388
# missing                  0.056469
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.240 p-value.
#
#
#
#
# Testing feature qn1005_hhw
#
# Group proportions for feature qn1005_hhw:
#
# qn1005_hhw
# Almost every day         0.052934
# At least once a week     0.051771
# Daily                    0.052270
# Less than once a week    0.022472
# Not at all               0.068309
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.058 p-value.
#
#
#
#
# Testing feature qn1006_hhw
#
# Group proportions for feature qn1006_hhw:
#
# qn1006_hhw
# no     0.050446
# yes    0.054670
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.467 p-value.
#
#
#
#
# Testing feature qn1007_hhw
#
# Group proportions for feature qn1007_hhw:
#
# qn1007_hhw
# no     0.047763
# yes    0.054606
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.321 p-value.
#
#
#
#
# Testing feature qn1008_hhw
#
# Group proportions for feature qn1008_hhw:
#
# qn1008_hhw
# missing    0.000000
# no         0.088670
# yes        0.052214
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.065 p-value.
#
#
#
#
# Testing feature qn1010_hhw
#
# Group proportions for feature qn1010_hhw:
#
# qn1010_hhw
# no     0.050628
# yes    0.059310
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.144 p-value.
#
#
#
#
# Testing feature qn1011_hhw
#
# Group proportions for feature qn1011_hhw:
#
# qn1011_hhw
# missing    0.000000
# no         0.050418
# yes        0.060284
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.232 p-value.
#
#
#
#
# Testing feature qn1012_hhw
#
# Group proportions for feature qn1012_hhw:
#
# qn1012_hhw
# missing    0.000000
# no         0.061694
# yes        0.051675
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.382 p-value.
#
#
#
#
# Testing feature qn1013_hhw
#
# Group proportions for feature qn1013_hhw:
#
# qn1013_hhw
# Bricks             0.074074
# Cement             0.053670
# Concrete           0.045455
# Earth/Sand/Dung    0.053082
# Mosaic or Tiles    0.031250
# Other              0.062500
# Stones             0.066667
# missing            0.000000
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.996 p-value.
#
#
#
#
# Testing feature qn1014_hhw
#
# Group proportions for feature qn1014_hhw:
#
# qn1014_hhw
# Iron        0.053625
# Other       0.000000
# Thatched    0.045455
# Tiles       0.000000
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.631 p-value.
#
#
#
#
# Testing feature qn01_104
#
# Group proportions for feature qn01_104:
#
# qn01_104
# female     0.047319
# male       0.053006
# missing    0.073733
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.105 p-value.
#
#
#
#
# Testing feature qn01_105
#
# Group proportions for feature qn01_105:
#
# qn01_105
# Household Head    0.051866
# missing           0.073733
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.050 p-value.
#
#
#
#
# Testing feature qn01_106
#
# Group proportions for feature qn01_106:
#
# qn01_106
# J1         0.000000
# J3         0.000000
# Other      0.250000
# P5         0.000000
# P7         0.000000
# S1         0.051888
# S2         0.000000
# S4         0.000000
# missing    0.073733
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.441 p-value.
#
#
#
#
# Testing feature shop_village
#
# Group proportions for feature shop_village:
#
# shop_village
# 0.0    0.036287
# 1.0    0.062443
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.000 p-value.
#
#
#
#
# Testing feature qn01_106_binned
#
# Group proportions for feature qn01_106_binned:
#
# qn01_106_binned
# Not S1     0.045455
# S1         0.051888
# missing    0.073733
# Name: died, dtype: float64
#
# z_test of difference in proportions has 0.145 p-value.
#
#
# Group means for feature qn206_totmalflag5:
# died
# 0.0    3.179275
# 1.0    3.200000
# Name: mean, dtype: float64
#
# t_test of difference in means has 0.677 p-value.
#
# Group means for feature qn1001_hhw:
# died
# 0.0    12.549007
# 1.0    11.908333
# Name: mean, dtype: float64
#
# t_test of difference in means has 0.348 p-value.
#
# Group means for feature qn1009_hhw:
# died
# 0.0    2.166104
# 1.0    1.803185
# Name: mean, dtype: float64
#
# t_test of difference in means has 0.002 p-value.
#
# Group means for feature qn01_103:
# died
# 0.0    39.809283
# 1.0    39.971694
# Name: mean, dtype: float64
#
# t_test of difference in means has 0.806 p-value.
#
# Group means for feature totalshops_village:
# died
# 0.0    0.751172
# 1.0    0.855556
# Name: mean, dtype: float64
#
# t_test of difference in means has 0.003 p-value.

# %%
test_results.sort(key = lambda x: x[1])
test_results
# Out:
# [('qn221_know', None),
#  ('parish_name', 3.8770528848572744e-11),
#  ('district_name', 3.9530068029998376e-11),
#  ('subcounty_name', 7.7663581479826325e-10),
#  ('village_name_old', 1.8088731898760795e-07),
#  ('shop_village', 4.9017612035980309e-06),
#  ('qn217_know', 4.1734943291762372e-05),
#  ('qn1009_hhw', 0.0021865108784860773),
#  ('qn216_know', 0.0024811452720023995),
#  ('totalshops_village', 0.0029485957739902309),
#  ('qn1002_hhw', 0.010025559581432253),
#  ('qn204_know', 0.015732693976202028),
#  ('qn210_know', 0.023659893496828725),
#  ('qn211a_know', 0.027190714743146108),
#  ('qn209b_know', 0.03232466838355473),
#  ('qn01_105', 0.049729368926687945),
#  ('qn211b_know', 0.051108664808094957),
#  ('qn212_know', 0.055765328236581362),
#  ('qn1005_hhw', 0.057899035327918881),
#  ('qn1008_hhw', 0.064880318180595822),
#  ('qn205_know', 0.071554718278568047),
#  ('qn211c_know', 0.071922609425635595),
#  ('qn01_104', 0.1053549642315269),
#  ('qn1010_hhw', 0.14362331631306594),
#  ('qn01_106_binned', 0.1445286916111431),
#  ('qn209a_know', 0.17020431917553022),
#  ('qn202_know', 0.18419119305306639),
#  ('qn201_know', 0.18900199071673096),
#  ('qn209c_know', 0.22621147678327028),
#  ('qn1011_hhw', 0.23209483420043919),
#  ('qn218_know', 0.23454517428872715),
#  ('qn1004_hhw', 0.24028917254149973),
#  ('qn206c_know', 0.2817369898616775),
#  ('qn1007_hhw', 0.32086350737216385),
#  ('qn1001_hhw', 0.34765016280557315),
#  ('qn213_know', 0.36163603709370618),
#  ('qn222_know', 0.36287189668876352),
#  ('qn1012_hhw', 0.3816314343390782),
#  ('qn227_know', 0.43569527442788153),
#  ('qn01_106', 0.44089143794867502),
#  ('qn214_know', 0.45571704924601775),
#  ('qn206d_know', 0.46323353122225464),
#  ('qn207a_know', 0.46633385100587199),
#  ('qn1006_hhw', 0.46671341828118429),
#  ('qn223_know', 0.47525472502867694),
#  ('qn219_know', 0.48354090033558195),
#  ('qn208_know', 0.50892797307893511),
#  ('qn1003_hhw', 0.54966137791586145),
#  ('qn226_know', 0.60846643481815299),
#  ('qn1014_hhw', 0.63132706964338081),
#  ('qn206_totmalflag5', 0.67731102677405208),
#  ('qn206b_know', 0.70465840589881035),
#  ('qn215_know', 0.74166684956871809),
#  ('qn220_know', 0.76159984562401817),
#  ('qn01_103', 0.80606215331562581),
#  ('qn206a_know', 0.83098669556617932),
#  ('qn225_know', 0.86100749867177906),
#  ('qn224_know', 0.8995295053445147),
#  ('qn1013_hhw', 0.99623155599038493),
#  ('qn203_know', 0.99729483106741257)]

# %% [markdown]
# ## Plot results

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plot_features_p_values(test_results, p_value_threshold): 
    res = pd.DataFrame(test_results, columns=['feature','p_value'])
    res.p_value = res.p_value.map(lambda x: 1 if pd.isnull(x) else x)
    res.sort_values(by='p_value', inplace=True)

    fig, ax = plt.subplots(figsize=(16, 25))

    bar_pos = np.arange(res.shape[0])

    palette = np.array(['green', 'red'])
    colors = palette[1* (res.p_value > p_value_threshold)]
                       
    rects = ax.barh(bar_pos, res.p_value,
                     align='center',
                     height=0.5, color=colors,
                     tick_label=res.feature)
    
    ax.set_xlabel('p_value', fontsize=14)
    ax.set_title('RCT questions p_values for correlation to child mortality', fontsize=20)
    
    ax.axvline(x=p_value_threshold, linestyle='dashed', color='darkgrey', alpha=0.5)
    
    fig.savefig('./test_results.png')

# %%
plot_features_p_values(test_results, 0.10)

# %%
def plot_feature_proportions(feature):
    labels = df.groupby(feature).mean()['died'].index.values
    prop = df.groupby(feature).mean()['died'].values
    size = df.groupby(feature).count()['died'].values
    se = np.sqrt((prop * (1 - prop)) / size)

    fig, ax = plt.subplots(figsize=(9,7))
    N = np.arange(len(labels))
    rects1 = ax.bar(N, prop, yerr=se, color='cornflowerblue')

    # add some text for labels, title and axes ticks
    ax.set_ylabel('Proportion', fontsize=14)
    ax.set_title('Proportion of deaths by category for %s' % feature, fontsize=20)
    ax.set_xticklabels(labels, rotation='vertical')
    plt.tight_layout()
    fig.savefig('./'+feature+'.png')

# %%
for test in test_results:
    if (test[1] < 0.05) & (not test[1] is None):
        plot_feature_proportions(test[0])

# %%
for test in test_results:
    if (test[1] < 0.05) & (not test[1] is None):
        print test
# Out:
# ('parish_name', 3.8770528848572744e-11)
# ('district_name', 3.9530068029998376e-11)
# ('subcounty_name', 7.7663581479826325e-10)
# ('village_name_old', 1.8088731898760795e-07)
# ('shop_village', 4.9017612035980309e-06)
# ('qn217_know', 4.1734943291762372e-05)
# ('qn1009_hhw', 0.0021865108784860773)
# ('qn216_know', 0.0024811452720023995)
# ('totalshops_village', 0.0029485957739902309)
# ('qn1002_hhw', 0.010025559581432253)
# ('qn204_know', 0.015732693976202028)
# ('qn210_know', 0.023659893496828725)
# ('qn211a_know', 0.027190714743146108)
# ('qn209b_know', 0.03232466838355473)
# ('qn01_105', 0.049729368926687945)

# %% [markdown]
# ## Fitting a Machine Learning Model

# %%
from data_preparation import DataPreparation

# %%
dp = DataPreparation()
dp._read_data()
df = dp._data
